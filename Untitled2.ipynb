# %% [markdown]
# <a href="https://colab.research.google.com/github/wertyuio1589/repoz1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/porsche_911.csv")

# %%
data.isnull()
# Out:
#       link  generation   engine  start_of_production  powertrain_architecture  \
# 0    False        False   False                False                    False
# 1    False        False   False                False                    False
# 2    False        False   False                False                    False
# 3    False        False   False                False                    False
# 4    False        False   False                False                    False
# ..     ...          ...     ...                  ...                      ...
# 283  False        False   False                False                    False
# 284  False        False   False                False                    False
# 285  False        False   False                False                    False
# 286  False        False   False                False                    False
# 287  False        False   False                False                    False
#
# ...

# %% [markdown]
# Типы кузовов Порше 911:

# %%
data['body_type'].unique()
# Out:
# array(['Off-road vehicle, Coupe ', 'Targa ', 'Roadster ', 'Cabriolet ',
#        'Coupe '], dtype=object)

# %% [markdown]
# корреляция максимальной скорости и мощности показывает прямую зависимость- чем больше мощность, тем выше максимальная скорость

# %%
x = data[['maximum_speed','power_per_litre']]
x.corr()
# Out:
#                  maximum_speed  power_per_litre
# maximum_speed         1.000000         0.819531
# power_per_litre       0.819531         1.000000

# %%
data['doors'].sum()
# Out:
# 576

# %%
data['start_of_production'].mean()
# Out:
# 2002.1458333333333

# %%
data['start_of_production'].median()
# Out:
# 2007.5

# %%
data['maximum_speed'].std()
# Out:
# 30.240970734013175

# %%
data['maximum_speed'].min()
# Out:
# 200.0

# %%
data['maximum_speed'].max()
# Out:
# 340.0

# %%
df=data.drop(1, axis=0,inplace=True)

# %%
df>=data
# Out:
#       link  generation   engine  start_of_production  powertrain_architecture  \
# 0    False        False   False                False                    False
# 2    False        False   False                False                    False
# 3    False        False   False                False                    False
# 4    False        False   False                False                    False
# 5    False        False   False                False                    False
# ..     ...          ...     ...                  ...                      ...
# 283  False        False   False                False                    False
# 284  False        False   False                False                    False
# 285  False        False   False                False                    False
# 286  False        False   False                False                    False
# 287  False        False   False                False                    False
#
# ...
